# %%
#Importation de nos librairies
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# **Chargement de nos differents jeu de données dans un dataframe**

# %%
#Dataframe pour les vehicules
df_vehicules = pd.read_csv("vehicules.csv")

#Dataframe des accidents
df_accidents =  pd.read_csv("accidents.csv")

df_vehicules.head()
# Out:
#    Num_acc Catégorie du véhicule Point de choc  Nombre de passagers  \
# 0        0          Motocyclette         Avant                    1
# 1        1        Véhicule Léger         Avant                    2
# 2        1            Bicyclette       Arrière                    1
# 3        1   Véhicule Utilitaire    Côté Droit                    1
# 4        2        Véhicule Léger         Avant                    2
#
#   Obstacle heurté
# 0           Fossé
# 1        Véhicule
# 2        Véhicule
# 3        Véhicule
# 4        Véhicule

# %%
df_accidents.head()
# Out:
#    Num_acc Conditions Atmosphériques Etat Surface       Catégorie Route  \
# 0        0                       NaN      Mouillé        Voie Communale
# 1        1                       NaN          Sec                   NaN
# 2        2                       NaN      Mouillé        Voie Communale
# 3        3                     Pluie          NaN  Route Départementale
# 4        4                       NaN      Mouillé                   NaN
#
#    Vitesse Maximale Autorisée  Nombre Véhicules Impliqués  \
# 0                        30.0                         NaN
# 1                        70.0                         3.0
# 2                        30.0                         2.0
# 3                         NaN                         NaN
# 4                        90.0                         NaN
#
#    Nombre Usagers Impliqués                 Date Conditions Lumineuses  \
# 0                       1.0  2022-01-04 09:12:15                   NaN
# ...

# %% [markdown]
# **Quelques informations sur nos dataframe**

# %%
#Pour les vehicules
df_vehicules.info()
df_vehicules.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17465 entries, 0 to 17464
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Num_acc                17465 non-null  int64
#  1   Catégorie du véhicule  17465 non-null  object
#  2   Point de choc          17465 non-null  object
#  3   Nombre de passagers    17465 non-null  int64
#  4   Obstacle heurté        17465 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 682.4+ KB
# Num_acc                  0
# Catégorie du véhicule    0
# Point de choc            0
# Nombre de passagers      0
# Obstacle heurté          0
# dtype: int64
